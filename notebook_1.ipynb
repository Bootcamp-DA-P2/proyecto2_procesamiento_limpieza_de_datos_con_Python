# %% [markdown]
# ## Alejandra

# %%
import pandas as pd

# %%
df = pd.read_csv(r"./dataSet/kiva_loans.csv")
original_df = df

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  str
#  4   sector              671205 non-null  str
#  5   use                 666973 non-null  str
#  6   country_code        671197 non-null  str
#  7   country             671205 non-null  str
#  8   region              614405 non-null  str
#  9   currency            671205 non-null  str
#  10  partner_id          657698 non-null  float64
#  11  posted_time         671205 non-null  str
#  12  disbursed_time      668809 non-null  str
#  13  funded_time         622874 non-null  str
#  14  term_in_months      671205 non-null  float64
#  15  lender_count        671205 non-null  int64
#  16  tags                499789 non-null  str
#  17  borrower_genders    666984 non-null  str
#  18  repayment_interval  671205 non-null  str
#  19  date                671205 non-null  str
# dtypes: float64(4), int64(2), str(14)
# memory usage: 102.4 MB

# %%
df.describe()
# Out:
#                  id  funded_amount    loan_amount     partner_id  \
# count  6.712050e+05  671205.000000  671205.000000  657698.000000
# mean   9.932486e+05     785.995061     842.397107     178.199616
# std    1.966113e+05    1130.398941    1198.660073      94.247581
# min    6.530470e+05       0.000000      25.000000       9.000000
# 25%    8.230720e+05     250.000000     275.000000     126.000000
# 50%    9.927800e+05     450.000000     500.000000     145.000000
# 75%    1.163653e+06     900.000000    1000.000000     204.000000
# max    1.340339e+06  100000.000000  100000.000000     536.000000
#
#        term_in_months   lender_count
# count   671205.000000  671205.000000
# mean        13.739022      20.590922
# std          8.598919      28.459551
# min          1.000000       0.000000
# 25%          8.000000       7.000000
# 50%         13.000000      13.000000
# 75%         14.000000      24.000000
# max        158.000000    2986.000000

# %%
print(df.shape)
# Out:
# (671205, 20)

# %%
display(df.head)
# Out:
# <bound method NDFrame.head of              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# 1       Transportation  to repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  to purchase an embroidery machine and a variet...
# 4                 Food                           to purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [True, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                                NaN
# 671203     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [True, u'to start a turducken farm.'] - this l...
#
#        country_code   country        region currency  partner_id  \
# 0                PK  Pakistan        Lahore      PKR       247.0
# 1                PK  Pakistan        Lahore      PKR       247.0
# 2                IN     India     Maynaguri      INR       334.0
# 3                PK  Pakistan        Lahore      PKR       247.0
# 4                PK  Pakistan  Abdul Hakeem      PKR       245.0
# ...             ...       ...           ...      ...         ...
# 671200           PY  Paraguay    Concepción      USD        58.0
# 671201           KE     Kenya           NaN      KES       138.0
# 671202           KE     Kenya           NaN      KES       138.0
# 671203           KE     Kenya           NaN      KES       138.0
# 671204           KE     Kenya           NaN      KES       138.0
#
#                       posted_time             disbursed_time  \
# 0       2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1       2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2       2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3       2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4       2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
# ...                           ...                        ...
# 671200  2017-07-25 16:55:34+00:00  2017-07-25 07:00:00+00:00
# 671201  2017-07-25 06:14:08+00:00  2017-07-24 07:00:00+00:00
# 671202  2017-07-26 00:02:07+00:00  2017-07-25 07:00:00+00:00
# 671203  2017-07-26 06:12:55+00:00  2017-07-25 07:00:00+00:00
# 671204  2017-07-26 06:31:46+00:00  2017-07-25 07:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# 0       2014-01-02 10:06:32+00:00            12.0            12
# 1       2014-01-02 09:17:23+00:00            11.0            14
# 2       2014-01-01 16:01:36+00:00            43.0             6
# 3       2014-01-01 13:00:00+00:00            11.0             8
# 4       2014-01-01 19:18:51+00:00            14.0            16
# ...                           ...             ...           ...
# 671200                        NaN            13.0             0
# 671201  2017-07-26 02:09:43+00:00            13.0             1
# 671202                        NaN            13.0             0
# 671203                        NaN            13.0             0
# 671204                        NaN            13.0             0
#
#                                 tags borrower_genders repayment_interval  \
# 0                                NaN           female          irregular
# 1                                NaN   female, female          irregular
# 2       user_favorite, user_favorite           female             bullet
# 3                                NaN           female          irregular
# 4                                NaN           female            monthly
# ...                              ...              ...                ...
# 671200                           NaN           female            monthly
# 671201                           NaN           female            monthly
# 671202                           NaN              NaN            monthly
# 671203                           NaN           female            monthly
# 671204                           NaN           female            monthly
#
#               date
# 0       2014-01-01
# 1       2014-01-01
# 2       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
# ...            ...
# 671200  2017-07-25
# 671201  2017-07-25
# 671202  2017-07-26
# 671203  2017-07-26
# 671204  2017-07-26
#
# [671205 rows x 20 columns]>

# %%
display(df.info)
# Out:
# <bound method DataFrame.info of              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# 1       Transportation  to repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  to purchase an embroidery machine and a variet...
# 4                 Food                           to purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [True, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                                NaN
# 671203     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [True, u'to start a turducken farm.'] - this l...
#
#        country_code   country        region currency  partner_id  \
# 0                PK  Pakistan        Lahore      PKR       247.0
# 1                PK  Pakistan        Lahore      PKR       247.0
# 2                IN     India     Maynaguri      INR       334.0
# 3                PK  Pakistan        Lahore      PKR       247.0
# 4                PK  Pakistan  Abdul Hakeem      PKR       245.0
# ...             ...       ...           ...      ...         ...
# 671200           PY  Paraguay    Concepción      USD        58.0
# 671201           KE     Kenya           NaN      KES       138.0
# 671202           KE     Kenya           NaN      KES       138.0
# 671203           KE     Kenya           NaN      KES       138.0
# 671204           KE     Kenya           NaN      KES       138.0
#
#                       posted_time             disbursed_time  \
# 0       2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1       2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2       2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3       2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4       2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
# ...                           ...                        ...
# 671200  2017-07-25 16:55:34+00:00  2017-07-25 07:00:00+00:00
# 671201  2017-07-25 06:14:08+00:00  2017-07-24 07:00:00+00:00
# 671202  2017-07-26 00:02:07+00:00  2017-07-25 07:00:00+00:00
# 671203  2017-07-26 06:12:55+00:00  2017-07-25 07:00:00+00:00
# 671204  2017-07-26 06:31:46+00:00  2017-07-25 07:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# 0       2014-01-02 10:06:32+00:00            12.0            12
# 1       2014-01-02 09:17:23+00:00            11.0            14
# 2       2014-01-01 16:01:36+00:00            43.0             6
# 3       2014-01-01 13:00:00+00:00            11.0             8
# 4       2014-01-01 19:18:51+00:00            14.0            16
# ...                           ...             ...           ...
# 671200                        NaN            13.0             0
# 671201  2017-07-26 02:09:43+00:00            13.0             1
# 671202                        NaN            13.0             0
# 671203                        NaN            13.0             0
# 671204                        NaN            13.0             0
#
#                                 tags borrower_genders repayment_interval  \
# 0                                NaN           female          irregular
# 1                                NaN   female, female          irregular
# 2       user_favorite, user_favorite           female             bullet
# 3                                NaN           female          irregular
# 4                                NaN           female            monthly
# ...                              ...              ...                ...
# 671200                           NaN           female            monthly
# 671201                           NaN           female            monthly
# 671202                           NaN              NaN            monthly
# 671203                           NaN           female            monthly
# 671204                           NaN           female            monthly
#
#               date
# 0       2014-01-01
# 1       2014-01-01
# 2       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
# ...            ...
# 671200  2017-07-25
# 671201  2017-07-25
# 671202  2017-07-26
# 671203  2017-07-26
# 671204  2017-07-26
#
# [671205 rows x 20 columns]>

# %% [markdown]
# ## LIMPIEZA DE DATOS

# %% [markdown]
# ### PASAR TIPO STR A DATATIME LAS FECHAS

# %%
df_type = df.loc[:,['posted_time', 'disbursed_time', 'funded_time', 'date']]
df_type.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   posted_time     671205 non-null  str
#  1   disbursed_time  668809 non-null  str
#  2   funded_time     622874 non-null  str
#  3   date            671205 non-null  str
# dtypes: str(4)
# memory usage: 20.5 MB

# %%
colum_df = ['posted_time', 'disbursed_time', 'funded_time', 'date']
for column in colum_df:
    df[column] = pd.to_datetime(df[column]) #Por cada columna cambia a tipo fecha

df_type = df.loc[:,['posted_time', 'disbursed_time', 'funded_time', 'date']]
df_type.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   posted_time     671205 non-null  datetime64[us, UTC]
#  1   disbursed_time  668809 non-null  datetime64[us, UTC]
#  2   funded_time     622874 non-null  datetime64[us, UTC]
#  3   date            671205 non-null  datetime64[us]
# dtypes: datetime64[us, UTC](3), datetime64[us](1)
# memory usage: 20.5 MB

# %% [markdown]
# ### NULOS

# %%
df.isnull().sum()
# Out:
# id                         0
# funded_amount              0
# loan_amount                0
# activity                   0
# sector                     0
# use                     4232
# country_code               8
# country                    0
# region                 56800
# currency                   0
# partner_id             13507
# posted_time                0
# disbursed_time          2396
# funded_time            48331
# term_in_months             0
# lender_count               0
# tags                  171416
# borrower_genders        4221
# repayment_interval         0
# date                       0
# dtype: int64

# %%
print(df.isnull().mean()*100)
# Out:
# id                     0.000000
# funded_amount          0.000000
# loan_amount            0.000000
# activity               0.000000
# sector                 0.000000
# use                    0.630508
# country_code           0.001192
# country                0.000000
# region                 8.462392
# currency               0.000000
# partner_id             2.012351
# posted_time            0.000000
# disbursed_time         0.356970
# funded_time            7.200632
# term_in_months         0.000000
# lender_count           0.000000
# tags                  25.538546
# borrower_genders       0.628869
# repayment_interval     0.000000
# date                   0.000000
# dtype: float64

# %%
print(df.columns)
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='str')

# %%
df = df.drop(columns=['tags'])
df.info() # eliminacion de columna tag ya que supera el 25%
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  str
#  4   sector              671205 non-null  str
#  5   use                 666973 non-null  str
#  6   country_code        671197 non-null  str
#  7   country             671205 non-null  str
#  8   region              614405 non-null  str
#  9   currency            671205 non-null  str
#  10  partner_id          657698 non-null  float64
#  11  posted_time         671205 non-null  datetime64[us, UTC]
#  12  disbursed_time      668809 non-null  datetime64[us, UTC]
#  13  funded_time         622874 non-null  datetime64[us, UTC]
#  14  term_in_months      671205 non-null  float64
#  15  lender_count        671205 non-null  int64
#  16  borrower_genders    666984 non-null  str
#  17  repayment_interval  671205 non-null  str
#  18  date                671205 non-null  datetime64[us]
# dtypes: datetime64[us, UTC](3), datetime64[us](1), float64(4), int64(2), str(9)
# memory usage: 97.3 MB

# %% [markdown]
# ### SUSTITUCION DE NULOS POR "NO ESPECIFICADO" EN CASO DE STRING Y POR LA MEDIA NUMERICA DE LA COLUMNA EN CASO DE NUMERO

# %%
#Seleccionar los nombres de las columnas que son texto
columns_str = df.select_dtypes(str).columns
print(columns_str)
for column in columns_str:
    df[column] = df[column].fillna("No especificado")

# Seleccionamos las que son int o float
columns_num = df.select_dtypes('number').columns

for column in columns_num:
    # Calculamos la mediana de la columna
    mediana = df[column].median()
    # Rellenamos los nulos de esa columna con su mediana
    df[column] = df[column].fillna(mediana)

# Verificamos que ya no quedan nulos
print(df.isnull().sum())
# Out:
# Index(['activity', 'sector', 'use', 'country_code', 'country', 'region',
#        'currency', 'borrower_genders', 'repayment_interval'],
#       dtype='str')
# id                        0
# funded_amount             0
# loan_amount               0
# activity                  0
# sector                    0
# use                       0
# country_code              0
# country                   0
# region                    0
# currency                  0
# partner_id                0
# posted_time               0
# disbursed_time         2396
# funded_time           48331
# term_in_months            0
# lender_count              0
# borrower_genders          0
# repayment_interval        0
# date                      0
# dtype: int64

# %%
df
# Out:
#              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# 1       Transportation  to repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  to purchase an embroidery machine and a variet...
# 4                 Food                           to purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [True, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                    No especificado
# 671203     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [True, u'to start a turducken farm.'] - this l...
#
#        country_code   country           region currency  partner_id  \
# 0                PK  Pakistan           Lahore      PKR       247.0
# 1                PK  Pakistan           Lahore      PKR       247.0
# 2                IN     India        Maynaguri      INR       334.0
# 3                PK  Pakistan           Lahore      PKR       247.0
# 4                PK  Pakistan     Abdul Hakeem      PKR       245.0
# ...             ...       ...              ...      ...         ...
# 671200           PY  Paraguay       Concepción      USD        58.0
# 671201           KE     Kenya  No especificado      KES       138.0
# 671202           KE     Kenya  No especificado      KES       138.0
# 671203           KE     Kenya  No especificado      KES       138.0
# 671204           KE     Kenya  No especificado      KES       138.0
#
#                      posted_time            disbursed_time  \
# 0      2014-01-01 06:12:39+00:00 2013-12-17 08:00:00+00:00
# 1      2014-01-01 06:51:08+00:00 2013-12-17 08:00:00+00:00
# 2      2014-01-01 09:58:07+00:00 2013-12-17 08:00:00+00:00
# 3      2014-01-01 08:03:11+00:00 2013-12-24 08:00:00+00:00
# 4      2014-01-01 11:53:19+00:00 2013-12-17 08:00:00+00:00
# ...                          ...                       ...
# 671200 2017-07-25 16:55:34+00:00 2017-07-25 07:00:00+00:00
# 671201 2017-07-25 06:14:08+00:00 2017-07-24 07:00:00+00:00
# 671202 2017-07-26 00:02:07+00:00 2017-07-25 07:00:00+00:00
# 671203 2017-07-26 06:12:55+00:00 2017-07-25 07:00:00+00:00
# 671204 2017-07-26 06:31:46+00:00 2017-07-25 07:00:00+00:00
#
#                      funded_time  term_in_months  lender_count  \
# 0      2014-01-02 10:06:32+00:00            12.0            12
# 1      2014-01-02 09:17:23+00:00            11.0            14
# 2      2014-01-01 16:01:36+00:00            43.0             6
# 3      2014-01-01 13:00:00+00:00            11.0             8
# 4      2014-01-01 19:18:51+00:00            14.0            16
# ...                          ...             ...           ...
# 671200                       NaT            13.0             0
# 671201 2017-07-26 02:09:43+00:00            13.0             1
# 671202                       NaT            13.0             0
# 671203                       NaT            13.0             0
# 671204                       NaT            13.0             0
#
#        borrower_genders repayment_interval       date
# 0                female          irregular 2014-01-01
# 1        female, female          irregular 2014-01-01
# 2                female             bullet 2014-01-01
# 3                female          irregular 2014-01-01
# 4                female            monthly 2014-01-01
# ...                 ...                ...        ...
# 671200           female            monthly 2017-07-25
# 671201           female            monthly 2017-07-25
# 671202  No especificado            monthly 2017-07-26
# 671203           female            monthly 2017-07-26
# 671204           female            monthly 2017-07-26
#
# [671205 rows x 19 columns]

# %% [markdown]
# En un inicio y debido a que los  2396 valores nulos de disbursed_time y los  48331 de funded_time representan solo el 0.36% y 7.2%  del dataSet respectivamente, pensamos en eliminar dichas filas. Sin embargo nos dimos cuenta que al hacerlo estabamos truncando la información relativa a los prestamos no financiados. Es por ello que decidimos dejarlos ya que no eran una gran cantidad de nulos.

# %%
#df = df.dropna() #borra las filas que tengan valores faltantes
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  str
#  4   sector              671205 non-null  str
#  5   use                 671205 non-null  str
#  6   country_code        671205 non-null  str
#  7   country             671205 non-null  str
#  8   region              671205 non-null  str
#  9   currency            671205 non-null  str
#  10  partner_id          671205 non-null  float64
#  11  posted_time         671205 non-null  datetime64[us, UTC]
#  12  disbursed_time      668809 non-null  datetime64[us, UTC]
#  13  funded_time         622874 non-null  datetime64[us, UTC]
#  14  term_in_months      671205 non-null  float64
#  15  lender_count        671205 non-null  int64
#  16  borrower_genders    671205 non-null  str
#  17  repayment_interval  671205 non-null  str
#  18  date                671205 non-null  datetime64[us]
# dtypes: datetime64[us, UTC](3), datetime64[us](1), float64(4), int64(2), str(9)
# memory usage: 97.3 MB

# %%
print(df.isnull().sum())
# Out:
# id                        0
# funded_amount             0
# loan_amount               0
# activity                  0
# sector                    0
# use                       0
# country_code              0
# country                   0
# region                    0
# currency                  0
# partner_id                0
# posted_time               0
# disbursed_time         2396
# funded_time           48331
# term_in_months            0
# lender_count              0
# borrower_genders          0
# repayment_interval        0
# date                      0
# dtype: int64

# %% [markdown]
# ### ELIMINACION DE DUPLICADOS

# %%
df.duplicated().sum() #cuenta el numero de duplicados
# Out:
# np.int64(0)

# %% [markdown]
# ### NORMALIZACION DE TEXTOS

# %%
for column in df.columns:
    if df[column].dtype == 'str':
        df[column] = df[column].str.strip().str.capitalize() #Eliminamos espacios en blanco y ponemos la primera letra en mayusculas

# %% [markdown]
# ### NORMALIZACION DE MONEDA
#  Eliminación de country code debido a redundancia con la columna de country y conversión de currency a dolares

# %%
df = df.drop(columns=['country_code']) #Eliminación de columna contry_code

# %%
import requests

# Obtenemos tasas de cambio
# response = requests.get('https://api.exchangerate-api.com/v4/latest/USD')
# rates_usd_base = response.json()['rates']

#Creamos un diccionario vacio al cual decimos que recorra el de rates_usd_base para invertir los valores
# rates_to_usd = {}
# for currency, rate in rates_usd_base.items():
    # rates_to_usd[currency] = 1 / rate

# df['currency'] = df['currency'].str.upper() #normalizamos a mayusculas para que coincidan con los datos de conversion de la API

# def get_rate(currency_code):
    # return rates_to_usd.get(currency_code, None) # En caso de no encontrar la moneda devolveremos None


#Creamos dos nuevas columnas para meter estos nuevos datos
# df['funded_amount_usd'] = df['funded_amount'] * df['currency'].apply(get_rate)
# df['loan_amount_usd'] = df['loan_amount'] * df['currency'].apply(get_rate)

# %%
df
# Out:
#              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food             To buy seasonal, fresh fruits to sell.
# 1       Transportation  To repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  To purchase an embroidery machine and a variet...
# 4                 Food                           To purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [true, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [true, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                    No especificado
# 671203     Agriculture  [true, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [true, u'to start a turducken farm.'] - this l...
#
#          country           region currency  partner_id  \
# 0       Pakistan           Lahore      Pkr       247.0
# 1       Pakistan           Lahore      Pkr       247.0
# 2          India        Maynaguri      Inr       334.0
# 3       Pakistan           Lahore      Pkr       247.0
# 4       Pakistan     Abdul hakeem      Pkr       245.0
# ...          ...              ...      ...         ...
# 671200  Paraguay       Concepción      Usd        58.0
# 671201     Kenya  No especificado      Kes       138.0
# 671202     Kenya  No especificado      Kes       138.0
# 671203     Kenya  No especificado      Kes       138.0
# 671204     Kenya  No especificado      Kes       138.0
#
#                      posted_time            disbursed_time  \
# 0      2014-01-01 06:12:39+00:00 2013-12-17 08:00:00+00:00
# 1      2014-01-01 06:51:08+00:00 2013-12-17 08:00:00+00:00
# 2      2014-01-01 09:58:07+00:00 2013-12-17 08:00:00+00:00
# 3      2014-01-01 08:03:11+00:00 2013-12-24 08:00:00+00:00
# 4      2014-01-01 11:53:19+00:00 2013-12-17 08:00:00+00:00
# ...                          ...                       ...
# 671200 2017-07-25 16:55:34+00:00 2017-07-25 07:00:00+00:00
# 671201 2017-07-25 06:14:08+00:00 2017-07-24 07:00:00+00:00
# 671202 2017-07-26 00:02:07+00:00 2017-07-25 07:00:00+00:00
# 671203 2017-07-26 06:12:55+00:00 2017-07-25 07:00:00+00:00
# 671204 2017-07-26 06:31:46+00:00 2017-07-25 07:00:00+00:00
#
#                      funded_time  term_in_months  lender_count  \
# 0      2014-01-02 10:06:32+00:00            12.0            12
# 1      2014-01-02 09:17:23+00:00            11.0            14
# 2      2014-01-01 16:01:36+00:00            43.0             6
# 3      2014-01-01 13:00:00+00:00            11.0             8
# 4      2014-01-01 19:18:51+00:00            14.0            16
# ...                          ...             ...           ...
# 671200                       NaT            13.0             0
# 671201 2017-07-26 02:09:43+00:00            13.0             1
# 671202                       NaT            13.0             0
# 671203                       NaT            13.0             0
# 671204                       NaT            13.0             0
#
#        borrower_genders repayment_interval       date
# 0                Female          Irregular 2014-01-01
# 1        Female, female          Irregular 2014-01-01
# 2                Female             Bullet 2014-01-01
# 3                Female          Irregular 2014-01-01
# 4                Female            Monthly 2014-01-01
# ...                 ...                ...        ...
# 671200           Female            Monthly 2017-07-25
# 671201           Female            Monthly 2017-07-25
# 671202  No especificado            Monthly 2017-07-26
# 671203           Female            Monthly 2017-07-26
# 671204           Female            Monthly 2017-07-26
#
# [671205 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  str
#  4   sector              671205 non-null  str
#  5   use                 671205 non-null  str
#  6   country             671205 non-null  str
#  7   region              671205 non-null  str
#  8   currency            671205 non-null  str
#  9   partner_id          671205 non-null  float64
#  10  posted_time         671205 non-null  datetime64[us, UTC]
#  11  disbursed_time      668809 non-null  datetime64[us, UTC]
#  12  funded_time         622874 non-null  datetime64[us, UTC]
#  13  term_in_months      671205 non-null  float64
#  14  lender_count        671205 non-null  int64
#  15  borrower_genders    671205 non-null  str
#  16  repayment_interval  671205 non-null  str
#  17  date                671205 non-null  datetime64[us]
# dtypes: datetime64[us, UTC](3), datetime64[us](1), float64(4), int64(2), str(8)
# memory usage: 92.2 MB

# %%
#Eliminar  funded_amount y loan_amount puesto que ya no son necesarias y podemos calcularas en base a funded_amount_usd y la tasa de conversión
# df = df.drop(columns=['funded_amount','loan_amount'])

# %%
print(df.columns)
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country', 'region', 'currency', 'partner_id', 'posted_time',
#        'disbursed_time', 'funded_time', 'term_in_months', 'lender_count',
#        'borrower_genders', 'repayment_interval', 'date'],
#       dtype='str')

# %% [markdown]
# Después de releer la documentación de Kiva nos percatamos de que las cifras de funded_amount y loan_amout ya estaban en USD por lo que el código anterior no tendría mucho sentido, pero deja abierta una via de investigación para evaluar la relevancia de los prestamos según el pais.

# %% [markdown]
# ### ELIMINACION DE COLUMNA ID Y PARTNER ID
# No son muy significativas para el análisis y en lugar de convertirlos a números, las eliminamos

# %%
df = df.drop(columns=['id'])

# %%
df = df.drop(columns=['partner_id'])

# %%
print (df.columns)
# Out:
# Index(['funded_amount', 'loan_amount', 'activity', 'sector', 'use', 'country',
#        'region', 'currency', 'posted_time', 'disbursed_time', 'funded_time',
#        'term_in_months', 'lender_count', 'borrower_genders',
#        'repayment_interval', 'date'],
#       dtype='str')

# %% [markdown]
# ### LIMPIEZA NUMERICA
# Redondeamos los datos numericos a dos decimales al tratarse de microprestamos, pues ambos decimales pueden ser de gran utilidad.
# Sin embargo redondearemos a enteros en el caso de los meses y los solicitantes del prestamos para una mayor claridad.

# %%
columns_num = df.select_dtypes('number').columns
df[columns_num] = df[columns_num].round(2) 
df[['term_in_months', 'lender_count']] = df[['term_in_months', 'lender_count']].astype(int)

# %% [markdown]
# ## ANALISIS EXPLORATORIO DEL DATASET

# %% [markdown]
# 1º LINEA DE ANALISIS: EVOLUCION MENSUAL Y ESTACIONALIDAD - EL FACTOR TIEMPO (date)

# %%
#Aseguramos formato fecha
df['date'] = pd.to_datetime(df['date'])
#Extraemos año y mes para analisis de estacionalidad
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
# Agrupamos por mes real
grupos_mensuales = df['date'].dt.to_period('M')
evolucion_mensual = df.groupby(grupos_mensuales).agg(
    conteo_prestamos=('funded_amount', 'count'),
    monto_total=('funded_amount', 'sum'),
    monto_promedio=('funded_amount', 'mean')
)

# %%
# Calculamos el crecimiento porcentual mes a mes
evolucion_mensual['crecimiento_vol_pct'] = evolucion_mensual['conteo_prestamos'].pct_change() * 100
# Mostramos resultado
print(evolucion_mensual.head(12))
# Out:
#          conteo_prestamos  monto_total  monto_promedio  crecimiento_vol_pct
# date
# 2014-01             11735   10345250.0      881.572220                  NaN
# 2014-02             13697   12381025.0      903.922392            16.719216
# 2014-03             13627   12023630.0      882.338739            -0.511061
# 2014-04             13509   11789590.0      872.721149            -0.865928
# 2014-05             14108   11610830.0      822.996172             4.434081
# 2014-06             14301   12260855.0      857.342494             1.368018
# 2014-07             15241   13062715.0      857.077292             6.572967
# 2014-08             14722   11963140.0      812.602907            -3.405288
# 2014-09             15405   12399960.0      804.930867             4.639315
# 2014-10             16377   13046885.0      796.659034             6.309640
# 2014-11             16484   13212440.0      801.531182             0.653355
# 2014-12             15028   12619750.0      839.749135            -8.832808

# %% [markdown]
# - CONCLUSION:
# El volumen de préstamos muestra una tendencia de crecimiento anual con picos máximos en el último trimestre (octubre-noviembre). Sin embargo, existe una estacionalidad negativa marcada en diciembre, donde el volumen cae drásticamente. Además, se observa que en los meses de mayor actividad, el monto promedio por préstamo tiende a disminuir, sugiriendo una mayor diversificación hacia microcréditos de menor escala.

# %%
#Aquí agrupamos todos los 'meses'..etc
estacionalidad = df.groupby('month').agg(
    promedio_mensual_prestamos=('funded_amount', 'count'),
    promedio_monto_solicitado=('funded_amount', 'mean')
).sort_values('month')
print("--- EVOLUCIÓN TEMPORAL (Primeras 10 filas) ---")
print(evolucion_mensual.head(10))

print("\n--- PATRÓN POR MES (ESTACIONALIDAD) ---")
print(estacionalidad)
# Out:
# --- EVOLUCIÓN TEMPORAL (Primeras 10 filas) ---
#          conteo_prestamos  monto_total  monto_promedio  crecimiento_vol_pct
# date
# 2014-01             11735   10345250.0      881.572220                  NaN
# 2014-02             13697   12381025.0      903.922392            16.719216
# 2014-03             13627   12023630.0      882.338739            -0.511061
# 2014-04             13509   11789590.0      872.721149            -0.865928
# 2014-05             14108   11610830.0      822.996172             4.434081
# 2014-06             14301   12260855.0      857.342494             1.368018
# 2014-07             15241   13062715.0      857.077292             6.572967
# 2014-08             14722   11963140.0      812.602907            -3.405288
# 2014-09             15405   12399960.0      804.930867             4.639315
# 2014-10             16377   13046885.0      796.659034             6.309640
#
# --- PATRÓN POR MES (ESTACIONALIDAD) ---
#        promedio_mensual_prestamos  promedio_monto_solicitado
# month
# 1                           53813                 849.381190
# 2                           60268                 818.008562
# 3                           69644                 806.240739
# 4                           60962                 813.386864
# 5                           67664                 754.151691
# 6                           66291                 714.937096
# 7                           51641                 750.298794
# 8                           45879                 792.309444
# 9                           48259                 775.205454
# 10                          49085                 772.718957
# 11                          50809                 766.321813
# 12                          46890                 832.285135

# %% [markdown]
# - CONCLUSION:
# El mes con  mayor volumen de prestamos es el mes de marzo con 67.583 préstamos. Podemos observar que hay un aumento de enero hasta marzo. Puede que venga motivado por el inicio de ciclos productivos o escolares en muchas regiones del mundo. A partir del mes de julio, el volumen cae significativamente y se mantiene en un nivel bajo y estable hasta final de año. Podemos observar que enero y febrero tienen los promedios de monto solicitados más altos a pesar de no ser los meses con más creéitos concedidos.

# %% [markdown]
# 2º LINEA DE ANALISIS: CUALES SON LOS PAISES EN LOS QUE MAS CREDITOS SE DAN

# %%
df.describe()
# Out:
#        funded_amount    loan_amount  term_in_months   lender_count  \
# count  671205.000000  671205.000000   671205.000000  671205.000000
# mean      785.995061     842.397107       13.739022      20.590922
# min         0.000000      25.000000        1.000000       0.000000
# 25%       250.000000     275.000000        8.000000       7.000000
# 50%       450.000000     500.000000       13.000000      13.000000
# 75%       900.000000    1000.000000       14.000000      24.000000
# max    100000.000000  100000.000000      158.000000    2986.000000
# std      1130.398941    1198.660073        8.598919      28.459551
#
#                              date           year          month
# count                      671205  671205.000000  671205.000000
# mean   2015-11-09 22:40:34.648133    2015.385584       6.165738
# min           2014-01-01 00:00:00    2014.000000       1.000000
# 25%           2014-12-17 00:00:00    2014.000000       3.000000
# 50%           2015-11-20 00:00:00    2015.000000       6.000000
# 75%           2016-10-06 00:00:00    2016.000000       9.000000
# max           2017-07-26 00:00:00    2017.000000      12.000000
# std                           NaN       1.052327       3.374374

# %%
df.loc[:,['country','funded_amount','loan_amount']]
# Out:
#          country  funded_amount  loan_amount
# 0       Pakistan          300.0        300.0
# 1       Pakistan          575.0        575.0
# 2          India          150.0        150.0
# 3       Pakistan          200.0        200.0
# 4       Pakistan          400.0        400.0
# ...          ...            ...          ...
# 671200  Paraguay            0.0         25.0
# 671201     Kenya           25.0         25.0
# 671202     Kenya            0.0         25.0
# 671203     Kenya            0.0         25.0
# 671204     Kenya            0.0         25.0
#
# [671205 rows x 3 columns]

# %%
country_top = df.groupby('country')['loan_amount'].sum().sort_values(ascending=False) #buscamos en el dataset en el la columna country y mostramos los valores de forma desdendente
country_top.head(10).to_frame()
# Out:
#                loan_amount
# country
# Philippines     55342225.0
# Kenya           34534300.0
# United states   31496375.0
# Peru            30867400.0
# Paraguay        29629075.0
# El salvador     26603650.0
# Cambodia        19872700.0
# Bolivia         19843250.0
# Rwanda          16646300.0
# Uganda          15389350.0

# %% [markdown]
# - CONLUSION: Estos son los 10 paises donde la suma de sus totales nos da una mayor cantidad de dinero solicitada

# %% [markdown]
# 3º LINEA DE ANALISIS: QUE PRESTAMOS RECIBEN MAS DINERO ¿LOS DE MAYOR NUMERO DE SOLICITANTES O LOS DE MENOR?

# %%
lenders = df.groupby('lender_count')['loan_amount'].max().sort_values(ascending=False)
lenders.head(5).to_frame()
# Out:
#               loan_amount
# lender_count
# 2986             100000.0
# 1569              50000.0
# 1441              50000.0
# 7                 50000.0
# 0                 50000.0

# %% [markdown]
# - CONCLUSION: Como conclusión de la tabla anterior deducimos que a mayor numero de personas solicitantes del préstamo mayor es la cuantía solicitada

# %% [markdown]
# 4º LINEA DE ANALISIS: ¿CUAL ES LA RELACION ENTRE LOS MONTOS? ¿HAY PRESTAMOS QUE SE QUEDAN SIN FINANCIAR?

# %%
df.loc[:,['funded_amount','loan_amount']]
# Out:
#         funded_amount  loan_amount
# 0               300.0        300.0
# 1               575.0        575.0
# 2               150.0        150.0
# 3               200.0        200.0
# 4               400.0        400.0
# ...               ...          ...
# 671200            0.0         25.0
# 671201           25.0         25.0
# 671202            0.0         25.0
# 671203            0.0         25.0
# 671204            0.0         25.0
#
# [671205 rows x 2 columns]

# %%
no_completados = (df['funded_amount'] < df['loan_amount']).sum()

cero_financiacion = (df['funded_amount'] == 0).sum() #Contamos cuantos tienen 0 financiación

print(f"Préstamos con financiación incompleta: {no_completados}")
print(f"Préstamos con CERO financiación: {cero_financiacion}")
# Out:
# Préstamos con financiación incompleta: 48328
# Préstamos con CERO financiación: 3383

# %%
pct_incompletos = (df['funded_amount'] < df['loan_amount']).mean() * 100

print(f"Porcentaje de prestamos sin completar: {pct_incompletos:.2f}%")
# Out:
# Porcentaje de prestamos sin completar: 7.20%

# %% [markdown]
# - CONCLUSION: Debido a que el porcentaje sin 7.2% podemos deducir que existe una gran demanda que la plataforma no logra cubrir.
